# %% [markdown]
# # Boston Housing: General EDA Template
# **Dr. Dave Wanik - University of Connecticut**
#
# ----------------------------------
# Try to fill in the blanks for memory everyday (type it, don't just copy/paste so that your fingers get used to the syntax!)
#
# You may not need to use all of these codes everytime, but you will use all of these often as your wrangle data.

# %% [markdown]
# ## Import modules, mount your Google Drive, read data
# Set up your environment

# %%
# import modules
import pandas as pd # for data analysis
import numpy as np # for numeric functions
import matplotlib.pyplot as plt # for plotting

# %% [markdown]
# ## Read data

# %% [markdown]
# ### From your Google Drive

# %%
# # mount your google drive
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# #read data from drive
# #on the lefthand side, navigate to your data and copy the path
# df = pd.read_csv("/content/drive/MyDrive/Online Materials/Prep/Module1_PythonDataAnalysis/1_WelcomeToPythonPt1/Data/Boston Housing.csv")

# %% [markdown]
# ### From a website
# How to read from Github.

# %%
# read data from github
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ### Reading a shareable file from Google Drive (preferred)
# If no senstive information!

# %%
# you can also read from a shareable link or mount your Drive!
# https://drive.google.com/file/d/1i7bmAV4Hu8rEJ-wm0GPmxG-EoQaK9K-X/view?usp=sharing
# !gdown 1i7bmAV4Hu8rEJ-wm0GPmxG-EoQaK9K-X
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1i7bmAV4Hu8rEJ-wm0GPmxG-EoQaK9K-X
# To: /content/Boston Housing.csv
# 100% 35.2k/35.2k [00:00<00:00, 51.8MB/s]

# %%
df = pd.read_csv('/content/Boston Housing.csv')

# %%
# check out the data - what do you see?
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ## Head, shape, column names, data types, missing values
# See what you're working with - any missing values? Wrong data types? Strange values?
#
# If there are missing values, you can a) delete or b) impute (constant value like 0 or -999, mean or median of column, forward fill, backfill, interpolate, etc.)

# %%
# head
df.head(n=7)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9

# %%
# shape
df.shape # rows, columns
# Out:
# (506, 14)

# %%
# column names
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# data types
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
# missing values by column
# link: https://thispointer.com/python-pandas-count-number-of-nan-or-missing-values-in-dataframe-also-row-column-wise/
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
# missing values in entire dataframe
# link: https://thispointer.com/python-pandas-count-number-of-nan-or-missing-values-in-dataframe-also-row-column-wise/
df.isnull().sum().sum()
# Out:
# 0

# %%
# df.info() is the one stop shop for inspecting a data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ## Statistics, percentiles
# Get some more granularity on numeric columns. Any strange values? Any 'logical' variables hiding as numerics?

# %%
# describe() gives summary statistics
df.describe()

# it looks like 'chas' is hiding as a float, we will ignore that for now (min=0, max=1)
# 'chas' is a logical/indicator/binary/flag/dummy variable for "Near Charles River"
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# calculate more detailed percentiles or stats on your own
# let's focus on the target variable 'medv'

# mean
print("This is the mean: ")
df['medv'].mean() # in this case we are using the mean() function from pandas, but we don't need to say pd.df['medv'].mean(),
                  # since it is already a dataframe, you can use ALL the pandas functionality
# Out:
# This is the mean:
# 22.532806324110677

# %%
# mean rounded to two decimal points
print("This is the mean rounded to two decimal points: ")
np.round(a=df['medv'].mean(),decimals=2) # we can use a round() function, just like in Excel
# Out:
# This is the mean rounded to two decimal points:
# 22.53

# %%
# median
print("This is the median: ") # print statements don't matter, but they make the output look nice
df['medv'].median() # this is the median function from pandas, but we don't say pd.df['medv'].median(),
                    # because it is already a dataframe, so you can use ALL of the pandas functionality
# Out:
# This is the median:
# 21.2

# %%
# mode
# sometimes in a numeric column, there might not be an interesting mode
print("This is the mode:")
df['medv'].mode() # 50 is the mode! Interesting... will be interesting to visualize what this distribution looks like
# Out:
# This is the mode:
# 0    50.0
# dtype: float64

# %%
# percentiles
# link: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.quantile.html
print("Here is the 10th percentile, which means 10% of the data lies below this value:")
df['medv'].quantile(q=)
# Out:
# Here is the 10th percentile, which means 10% of the data lies below this value:
# 12.75

# %%
# let's look at the 10, 25, 50, 75, 90 percentiles
print("Here are various percentiles of the distribution:")
df['medv'].quantile(q=[0, 0.01, 0.025, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99, 1])

# notice how we entered the values as a list inside the function (square brackets [])
# check your work! scroll back up to describe and look at if the values line up (like 25, 50 and 75)
# Out:
# Here are various percentiles of the distribution:
# 0.000     5.000
# 0.010     7.010
# 0.025     8.300
# 0.050    10.200
# 0.100    12.750
# 0.250    17.025
# 0.500    21.200
# 0.750    25.000
# 0.900    34.800
# 0.950    43.400
# 0.990    50.000
# 1.000    50.000
# Name: medv, dtype: float64

# %% [markdown]
# ## Flag variables
# Convert some variables to 0 or 1 to help subset, explore trends

# %%
# make a new column to recode the target variable 'medv' to a 0 or 1
# 0 if less than or equal to the mean
# 1 if greater than the mean

# one line of code! we made a new column and populated it
df['FLAG_medv'] = np.where(df['medv'] <= np.mean(df['medv']), 0, 1)

# check your work!
print('The mean of medv is:', df['medv'].mean())
df.head()
# Out:
# The mean of medv is: 22.532806324110677
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv  FLAG_medv
# 0  396.90   4.98  24.0          1
# 1  396.90   9.14  21.6          0
# 2  392.83   4.03  34.7          1
# 3  394.63   2.94  33.4          1
# 4  396.90   5.33  36.2          1

# %% [markdown]
# ## Subsetting rows and columns
# Sometimes data has extra columns you're not interested in... drop them! Other times you may want to focus on just a subset of data.

# %%
# subset all rows where FLAG_medv = 0, we'll call this 'lowData'
lowData = df[df['FLAG_medv'] == 0]
print(lowData.shape) # make sure you got something... at least some rows... not empty...
                      # if you want to print two things in one cell, the first needs a print statement
                      
lowData.head() # check your work
# Out:
# (297, 15)
#        crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
#
#     ptratio       b  lstat  medv  FLAG_medv
# 1      17.8  396.90   9.14  21.6          0
# 8      15.2  386.63  29.93  16.5          0
# 9      15.2  386.71  17.10  18.9          0
# 10     15.2  392.52  20.45  15.0          0
# 11     15.2  396.90  13.27  18.9          0

# %%
# subset all rows where FLAG_medv = 0, we'll call this 'lowData'
# copy and paste the text above and reuse
highData = df[df['FLAG_medv'] == 1]
print(highData.shape) # make sure you got something... at least some rows... not empty...
                      # if you want to print two things in one cell, the first needs a print statement
                      
highData.head() # check your work
# Out:
# (209, 15)
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         b  lstat  medv  FLAG_medv
# 0  396.90   4.98  24.0          1
# 2  392.83   4.03  34.7          1
# 3  394.63   2.94  33.4          1
# 4  396.90   5.33  36.2          1
# 5  394.12   5.21  28.7          1

# %%
# let's try two conditions
# | is the or operator
tmp = df[(df['FLAG_medv']==0) | (df['rad']==1)]
print(tmp.shape)
tmp.head()
# Out:
# (306, 15)
#        crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
#
#     ptratio       b  lstat  medv  FLAG_medv
# 0      15.3  396.90   4.98  24.0          1
# 1      17.8  396.90   9.14  21.6          0
# 8      15.2  386.63  29.93  16.5          0
# 9      15.2  386.71  17.10  18.9          0
# 10     15.2  392.52  20.45  15.0          0

# %%
# let's try two conditions
# & is the and operator
# be careful of = (assignment) vs. == (identically equal to)
tmp = df[(df['FLAG_medv']==0) & (df['rad']==1)]
print(tmp.shape)
tmp.head()
# Out:
# (11, 15)
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 254  0.04819  80.0   3.64     0  0.3920  6.108  32.0  9.2203    1  315
# 255  0.03548  80.0   3.64     0  0.3920  5.876  19.1  9.2203    1  315
# 285  0.01096  55.0   2.25     0  0.3890  6.453  31.9  7.3073    1  300
# 286  0.01965  80.0   1.76     0  0.3850  6.230  31.5  9.0892    1  241
# 331  0.05023  35.0   6.06     0  0.4379  5.706  28.4  6.6407    1  304
#
#      ptratio       b  lstat  medv  FLAG_medv
# 254     16.4  392.89   6.57  21.9          0
# 255     16.4  395.18   9.25  20.9          0
# 285     15.3  394.72   8.23  22.0          0
# 286     18.2  341.60  12.93  20.1          0
# 331     16.9  394.02  12.43  17.1          0

# %%
# do the number of rows in lowData and highData equal the original rows?
tmpRows = lowData.shape[0] + highData.shape[0]
tmpRows
# Out:
# 506

# %%
# a logical statement
tmpRows == df.shape[0] # TRUE! it worked
# Out:
# True

# %% [markdown]
# ## Group By (pivot tables)
# Count, min, max, mean, standard deviation

# %%
# link: https://stackoverflow.com/questions/33575587/pandas-dataframe-how-to-apply-describe-to-each-group-and-add-to-new-columns
df.groupby('FLAG_medv').describe() #ONE LINE OF CODE! Too easy.
# now we can compare the attributes of all the numeric variables
# recall that describe() is only useful for numeric variables
# Out:
#             crim                                                          \
#            count      mean        std      min     25%      50%      75%
# FLAG_medv
# 0          297.0  5.563153  10.668584  0.01096  0.1396  0.84054  7.67202
# 1          209.0  0.842998   2.125546  0.00632  0.0536  0.10469  0.46296
#
#                        zn             ...  lstat          medv             \
#                max  count       mean  ...    75%    max  count       mean
# FLAG_medv                             ...
# 0          88.9762  297.0   4.587542  ...  19.88  37.97  297.0  16.870370
# 1          14.4383  209.0  20.992823  ...   9.16  29.55  209.0  30.579426
#
#
#                 std   min   25%   50%   75%   max
# FLAG_medv
# 0          4.233162   5.0  13.9  18.0  20.3  22.5
# 1          8.308060  22.6  24.0  27.9  34.6  50.0
#
# [2 rows x 112 columns]

# %%
# pivot table
# https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html
table = pd.pivot_table(df, values='crim', index=['FLAG_medv'],
                    columns=['chas'], aggfunc=np.mean)
table
# Out:
# chas              0         1
# FLAG_medv
# 0          5.746519  2.115867
# 1          0.757228  1.653523

# %% [markdown]
# ## Correlation
# Explore the relationship between numeric variables

# %%
# link: https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas

df.corr(method='spearman')

#plt.matshow(df.corr())
#plt.show()

# this is OK... but there's no legend and no interesting labels...
# keep scrolling the article and you will find the sns plot (seaborn)
# Out:
#                crim        zn     indus      chas       nox        rm  \
# crim       1.000000 -0.571660  0.735524  0.041537  0.821465 -0.309116
# zn        -0.571660  1.000000 -0.642811 -0.041937 -0.634828  0.361074
# indus      0.735524 -0.642811  1.000000  0.089841  0.791189 -0.415301
# chas       0.041537 -0.041937  0.089841  1.000000  0.068426  0.058813
# nox        0.821465 -0.634828  0.791189  0.068426  1.000000 -0.310344
# rm        -0.309116  0.361074 -0.415301  0.058813 -0.310344  1.000000
# age        0.704140 -0.544423  0.679487  0.067792  0.795153 -0.278082
# dis       -0.744986  0.614627 -0.757080 -0.080248 -0.880015  0.263168
# rad        0.727807 -0.278767  0.455507  0.024579  0.586429 -0.107492
# tax        0.729045 -0.371394  0.664361 -0.044486  0.649527 -0.271898
# ptratio    0.465283 -0.448475  0.433710 -0.136065  0.391309 -0.312923
# b         -0.360555  0.163135 -0.285840 -0.039810 -0.296662  0.053660
# lstat      0.634760 -0.490074  0.638747 -0.050575  0.636828 -0.640832
# medv      -0.558891  0.438179 -0.578255  0.140612 -0.562609  0.633576
# FLAG_medv -0.399356  0.385861 -0.478698  0.087687 -0.428196  0.589548
#
#                 age       dis       rad       tax   ptratio         b  \
# crim       0.704140 -0.744986  0.727807  0.729045  0.465283 -0.360555
# zn        -0.544423  0.614627 -0.278767 -0.371394 -0.448475  0.163135
# indus      0.679487 -0.757080  0.455507  0.664361  0.433710 -0.285840
# chas       0.067792 -0.080248  0.024579 -0.044486 -0.136065 -0.039810
# nox        0.795153 -0.880015  0.586429  0.649527  0.391309 -0.296662
# rm        -0.278082  0.263168 -0.107492 -0.271898 -0.312923  0.053660
# age        1.000000 -0.801610  0.417983  0.526366  0.355384 -0.228022
# dis       -0.801610  1.000000 -0.495806 -0.574336 -0.322041  0.249595
# rad        0.417983 -0.495806  1.000000  0.704876  0.318330 -0.282533
# tax        0.526366 -0.574336  0.704876  1.000000  0.453345 -0.329843
# ptratio    0.355384 -0.322041  0.318330  0.453345  1.000000 -0.072027
# b         -0.228022  0.249595 -0.282533 -0.329843 -0.072027  1.000000
# lstat      0.657071 -0.564262  0.394322  0.534423  0.467259 -0.210562
# medv      -0.547562  0.445857 -0.346776 -0.562411 -0.555905  0.185664
# FLAG_medv -0.436862  0.315960 -0.221081 -0.412474 -0.484834  0.127841
#
#               lstat      medv  FLAG_medv
# crim       0.634760 -0.558891  -0.399356
# zn        -0.490074  0.438179   0.385861
# indus      0.638747 -0.578255  -0.478698
# chas      -0.050575  0.140612   0.087687
# nox        0.636828 -0.562609  -0.428196
# rm        -0.640832  0.633576   0.589548
# age        0.657071 -0.547562  -0.436862
# dis       -0.564262  0.445857   0.315960
# rad        0.394322 -0.346776  -0.221081
# tax        0.534423 -0.562411  -0.412474
# ptratio    0.467259 -0.555905  -0.484834
# b         -0.210562  0.185664   0.127841
# lstat      1.000000 -0.852914  -0.715329
# medv      -0.852914  1.000000   0.852862
# FLAG_medv -0.715329  0.852862   1.000000

# %%
# pretty! we haven't used seaborn yet, but it is certainly a nice library
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()

# notice perfect correlation along the diagonal (as expected)
# it's most interesting to look at correlation among predictors, and with the target

# %%
corr = df.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_12051_row0_col0, #T_12051_row1_col1, #T_12051_row2_col2, #T_12051_row3_col3, #T_12051_row4_col4, #T_12051_row5_col5, #T_12051_row6_col6, #T_12051_row7_col7, #T_12051_row8_col8, #T_12051_row9_col9, #T_12051_row10_col10, #T_12051_row11_col11, #T_12051_row12_col12, #T_12051_row13_col13, #T_12051_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_12051_row0_col1, #T_12051_row14_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_12051_row0_col2, #T_12051_row2_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_12051_row0_col3, #T_12051_row0_col13, #T_12051_row4_col13, #T_12051_row9_col13, #T_12051_row14_col2 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_12051_row0_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_12051_row0_col5, #T_12051_row4_col5, #T_12051_row10_col5, #T_12051_row14_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_12051_row0_col6 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_12051_row0_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_12051_row0_col8, #T_12051_row6_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_12051_row0_col9 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_12051_row0_col10, #T_12051_row12_col10, #T_12051_row13_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_12051_row0_col11, #T_12051_row2_col1, #T_12051_row4_col7, #T_12051_row7_col0, #T_12051_row7_col2, #T_12051_row7_col4, #T_12051_row7_col6, #T_12051_row7_col8, #T_12051_row7_col9, #T_12051_row10_col3, #T_12051_row12_col5, #T_12051_row12_col13, #T_12051_row12_col14, #T_12051_row13_col10, #T_12051_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_12051_row0_col12, #T_12051_row4_col12, #T_12051_row5_col13, #T_12051_row9_col8 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_12051_row0_col14, #T_12051_row14_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_12051_row1_col0, #T_12051_row13_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_12051_row1_col2, #T_12051_row2_col7 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_12051_row1_col3, #T_12051_row11_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_12051_row1_col4, #T_12051_row1_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_12051_row1_col5, #T_12051_row5_col1, #T_12051_row6_col8 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_12051_row1_col6, #T_12051_row8_col3, #T_12051_row11_col8, #T_12051_row13_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_12051_row1_col7, #T_12051_row12_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_12051_row1_col8, #T_12051_row2_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_12051_row1_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_12051_row1_col11 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_12051_row1_col12, #T_12051_row2_col3, #T_12051_row14_col0, #T_12051_row14_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_12051_row1_col13, #T_12051_row6_col9 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_12051_row1_col14, #T_12051_row10_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_12051_row2_col4 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_12051_row2_col5, #T_12051_row2_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_12051_row2_col6 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_12051_row2_col8, #T_12051_row2_col10, #T_12051_row14_col7 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_12051_row2_col9 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_12051_row2_col11, #T_12051_row8_col11 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_12051_row2_col12, #T_12051_row12_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_12051_row3_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_12051_row3_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_12051_row3_col2, #T_12051_row3_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_12051_row3_col4 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_12051_row3_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_12051_row3_col7, #T_12051_row11_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_12051_row3_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_12051_row3_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_12051_row3_col10, #T_12051_row8_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_12051_row3_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_12051_row3_col12 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_12051_row3_col13 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_12051_row3_col14 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_12051_row4_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_12051_row4_col1, #T_12051_row13_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_12051_row4_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_12051_row4_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_12051_row4_col6 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_12051_row4_col8 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_12051_row4_col9, #T_12051_row8_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_12051_row4_col10, #T_12051_row5_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_12051_row4_col11, #T_12051_row7_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_12051_row4_col14, #T_12051_row6_col13, #T_12051_row9_col1, #T_12051_row12_col7 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_12051_row5_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_12051_row5_col2, #T_12051_row5_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_12051_row5_col3, #T_12051_row13_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_12051_row5_col4, #T_12051_row5_col11 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_12051_row5_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_12051_row5_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_12051_row5_col10, #T_12051_row7_col12, #T_12051_row11_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_12051_row5_col12 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_12051_row5_col14 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_12051_row6_col0 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_12051_row6_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_12051_row6_col3, #T_12051_row9_col14 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_12051_row6_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_12051_row6_col5, #T_12051_row8_col1, #T_12051_row11_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_12051_row6_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_12051_row6_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_12051_row6_col11 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_12051_row6_col12, #T_12051_row8_col9, #T_12051_row9_col4 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_12051_row6_col14, #T_12051_row9_col7, #T_12051_row10_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_12051_row7_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_12051_row7_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_12051_row7_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_12051_row7_col11 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_12051_row7_col13 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_12051_row7_col14, #T_12051_row11_col7 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_12051_row8_col0, #T_12051_row9_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_12051_row8_col2 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_12051_row8_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_12051_row8_col6, #T_12051_row10_col2, #T_12051_row10_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_12051_row8_col7 {
#   background-color: #

# %% [markdown]
# ## Univariate Plots
# Boxplots, kernel density plots, histograms

# %%
# show histograms of ALL variables
# histograms allow you to see the shape of the distribution... binned data...
df.hist(figsize=(15,10)) # this makes the histogram plot
plt.tight_layout() # space stuff out nicely (what happens without this?)
plt.show()

# %%
# make a histogram of one variable
df['crim'].hist(bins=10, color='orange')
plt.title('My First Boxplot')
plt.ylabel('Frequency')
plt.xlabel('Crime rate')
plt.show()

# %%
# boxplots
df.boxplot('medv', color='red') # grab the dataframe then select the 'medv' column
plt.ylabel('Median House Value ($)')
plt.title("Boxplot of Median House Value ($)")
plt.show()

# %%
df['crim'].plot.density() # notice the difference in syntax! where does medv go?
plt.xlim([0,np.max(df['crim'])])
plt.show()                # grab the column of interest then make a plot

# %% [markdown]
# ## Bivariate Plots
# Scatterplots

# %%
# scatterplot of all variables
# this is known as a 'pair plot'
# google scaterplot matrix pandas and you will find this:
# link: https://www.marsja.se/pandas-scatter-matrix-pair-plot/
pd.plotting.scatter_matrix(df, figsize=(10,10)) # ONE LINE OF CODE!
plt.show() # add this to get rid of the nasty text...

# %%
# here's another one
pd.plotting.scatter_matrix(df, diagonal='kde', figsize=(10,10)) #kde means 'kernel density estimate'
plt.show() # get's a little hard to see with MANY variables

# %%
# here's an easy plot of x = crim and y = medv
df.plot.scatter(x='crim', y='medv', color='red') # notice you just need the names of the columns
plt.xlabel("CRIME")
plt.ylabel("MEDIAN HOUSE PRICE")
plt.title("CRIME vs. MEDIAN HOUSE PRICE")
plt.show()

# every plot you make should have sensible labels and titles! NO EXCUSE!

# you can get fancy and add a smoother...
# link: https://stackoverflow.com/questions/23784399/how-to-visualize-a-nonlinear-relationship-in-a-scatter-plot

# %%
# let's make a directory called "Results" and save a plot there
# link: https://stackoverflow.com/questions/54172874/making-two-new-directory-in-google-colab-and-join-them
import tensorflow as tf

#Create a new directory (a folder) in your Drive
resultDir = ''
tf.io.gfile.mkdir(resultDir) # go and check your Google Drive and see if it made it!

# %%
# try to save that file
df.plot.scatter(x='crim', y='medv', color='red') # notice you just need the names of the columns
plt.xlabel("CRIME")
plt.ylabel("MEDIAN HOUSE PRICE")
plt.title("CRIME vs. MEDIAN HOUSE PRICE")
# plt.show() ### DON'T SHOW THE PLOT IF YOU ARE TRYING TO SAVE IT!
plt.savefig(resultDir + "myPlot1.png") # might take 10 SECONDS to appear!

# %%
# advanced - make two scatterplots side by side, these are known as subplots
# link: https://matplotlib.org/3.1.0/gallery/subplots_axes_and_figures/subplots_demo.html

# %% [markdown]
# ## Pandas profiler
# For a quick, automated check of the data... coding your own is best, but this is good for a quick check.

# %%
# link: https://stackoverflow.com/questions/53085501/how-to-upgrade-pandas-on-google-colab
# you may need to update pandas
# !pip install pandas==0.23.4 # restart your runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas==0.23.4
#   Downloading pandas-0.23.4.tar.gz (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 86.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.8/dist-packages (from pandas==0.23.4) (2.8.2)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.8/dist-packages (from pandas==0.23.4) (2022.7)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from pandas==0.23.4) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.5.0->pandas==0.23.4) (1.15.0)
# Building wheels for collected packages: pandas
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for pandas (setup.py) ... error
#   ERROR: Failed building wheel for pandas
#   Running setup.py clean for pandas
# Failed to build pandas
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pandas did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Running setup.py install for pandas ... error
#   WARNING: No metadata found in /usr/local/lib/python3.8/dist-packages
#   Rolling back uninstall of pandas
#   Moving to /usr/local/lib/python3.8/dist-packages/pandas-1.3.5.dist-info/
#    from /usr/local/lib/python3.8/dist-packages/~andas-1.3.5.dist-info
#   Moving to /usr/local/lib/python3.8/dist-packages/pandas/
#    from /usr/local/lib/python3.8/dist-packages/~andas
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# link: https://towardsdatascience.com/exploratory-data-analysis-with-pandas-profiling-de3aae2ddff3
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof # show the report
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-8369cf477c4e> in <module>
#       1 # link: https://towardsdatascience.com/exploratory-data-analysis-with-pandas-profiling-de3aae2ddff3
#       2 from pandas_profiling import ProfileReport
# ----> 3 prof = ProfileReport(df)
#       4 prof # show the report
#
# /usr/local/lib/python3.8/dist-packages/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      64         sample = kwargs.get('sample', df.head())
#      65
# ---> 66         description_set = describe(df, **kwargs)
#      67
#      68         self.html = to_html(sample,
#
# /usr/local/lib/python3.8/dist-packages/pandas_profiling/describe.py in describe(df, bins, check_correlation, correlation_threshold, correlation_overrides, check_recoded, pool_size, **kwargs)
#     390             if name not in names:
#     391                 names.append(name)
# --> 392     variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#     393     variable_stats.columns.names = df.columns.names
#     394
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %%
# save the report on your Google Drive for later
prof.to_file(resultDir + 'BostonProfile.html') # go check your result directory!
                                        # you may need to hit refresh

# %%
# note that we could have used this on low data, high data as well!
